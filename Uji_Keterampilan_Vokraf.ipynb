# %% [markdown]
# <a href="https://colab.research.google.com/github/ihdamaulidianf/Data-Business-Analysist/blob/main/Uji_Keterampilan_Vokraf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORT DATA & LIBRARY**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     275             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     276         )
# --> 277       raise ValueError('mount failed' + extra_reason)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uk = pd.read_csv("/content/drive/MyDrive/Prakerja Uji Keterampilan/Untitled spreadsheet - Sheet1.csv")

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS (EDA)**

# %%
uk
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line Unit price Quantity    Tax 5%      Total  \
# 0         Health and beauty      74.69     7,00   261.415  5.489.715
# 1    Electronic accessories      15.28     5,00      3.82      80.22
# 2        Home and lifestyle      46.33     7,00   162.155  3.405.255
# ...

# %%
uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   object
#  7   Quantity                 1000 non-null   object
#  8   Tax 5%                   1000 non-null   object
#  9   Total                    1000 non-null   object
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   object
# ...

# %%
uk['Unit price'] = pd.to_numeric(uk['Unit price'], errors='coerce')
uk['Quantity'] = pd.to_numeric(uk['Quantity'], errors='coerce')
uk['Tax 5%'] = pd.to_numeric(uk['Tax 5%'], errors='coerce')
uk['Total'] = pd.to_numeric(uk['Total'], errors='coerce')
uk['cogs'] = pd.to_numeric(uk['cogs'], errors='coerce')
uk['gross margin percentage'] = pd.to_numeric(uk['gross margin percentage'], errors='coerce')
uk['gross income'] = pd.to_numeric(uk['gross income'], errors='coerce')

# %%
uk['Date'] = pd.to_datetime(uk['Date'])
# Out:
# <ipython-input-31-a1324dc42c5a>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   uk['Date'] = pd.to_datetime(uk['Date'])

# %%
uk.describe()

# %%
uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               950 non-null    float64
#  7   Quantity                 0 non-null      float64
#  8   Tax 5%                   936 non-null    float64
#  9   Total                    830 non-null    float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
sns.heatmap(uk.corr(numeric_only=True), annot=True) #pakai heatmap
# Out:
# <Axes: >

# %%
from scipy import stats

# Menghitung z-score untuk setiap nilai
z_scores = stats.zscore(df['A'])

# Menentukan outlier (z-score > 3 atau z-score < -3)
outliers_z = df[np.abs(z_scores) > 3]
print("Outliers berdasarkan z-score:\n", outliers_z)
